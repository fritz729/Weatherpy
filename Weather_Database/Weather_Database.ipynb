# %%
# Import Dependancies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
from config import weather_api_key
import requests
import time
from datetime import datetime
#Create a URL variable for the API request
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Random Latitudes
lats = np.random.uniform(-90, 90, 1500)
#Random Longitudes
lngs = np.random.uniform(-180, 180, 1500)

#combined
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list for query
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 607

# %%
# Create a list to hold the weather data from the API query
city_data = []

# Create counters for request loops
record_count = 1
set_count = 1

# Print initiating text for the request query loop
print("Beginning data collection")
print("-------------------------")

# Loop through cities in the cities list
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for API request criteria
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create request URL for each city
    city_url = url + "&q=" + city.replace(" ", "+")
      
    #Log in using the URL and collect and record the set number and city.
    print(f"Processing {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count variable
    record_count += 1
    
# Run API request with error management for each city in the cities list
    try:
        # Parse the JSON and retrieve the needed data
        city_weather = requests.get(city_url).json()
        city_weather
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into the city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
        
        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
        
#Indicate the data loading is completed.
print("-----------------------")
print("Data Retrieval Complete")
print("-----------------------")
# Out:
# Beginning data collection
# -------------------------
# Processing 1 of Set 1 | port hardy
# Processing 2 of Set 1 | mayo
# Processing 3 of Set 1 | moose factory
# Processing 4 of Set 1 | cherskiy
# Processing 5 of Set 1 | chuy
# Processing 6 of Set 1 | gisborne
# Processing 7 of Set 1 | fallon
# Processing 8 of Set 1 | harrisonburg
# Processing 9 of Set 1 | qaqortoq
# Processing 10 of Set 1 | nhulunbuy
# Processing 11 of Set 1 | semnan
# Processing 12 of Set 1 | ostrovnoy
# Processing 13 of Set 1 | kalabo
# Processing 14 of Set 1 | te anau
# Processing 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing 16 of Set 1 | ust-maya
# Processing 17 of Set 1 | hartselle
# Processing 18 of Set 1 | dali
# Processing 19 of Set 1 | nogales
# Processing 20 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing 21 of Set 1 | ushuaia
# Processing 22 of Set 1 | umm durman
# City not found. Skipping...
# Processing 23 of Set 1 | matara
# Processing 24 of Set 1 | hermanus
# Processing 25 of Set 1 | airai
# Processing 26 of Set 1 | punta arenas
# Processing 27 of Set 1 | saint-philippe
# Processing 28 of Set 1 | bredasdorp
# Processing 29 of Set 1 | yellowknife
# Processing 30 of Set 1 | east london
# Processing 31 of Set 1 | atuona
# Processing 32 of Set 1 | hithadhoo
# Processing 33 of Set 1 | new norfolk
# Processing 34 of Set 1 | hilo
# Processing 35 of Set 1 | barrow
# Processing 36 of Set 1 | taybad
# Processing 37 of Set 1 | kahului
# Processing 38 of Set 1 | kjollefjord
# Processing 39 of Set 1 | rikitea
# Processing 40 of Set 1 | kodiak
# Processing 41 of Set 1 | busselton
# Processing 42 of Set 1 | russell
# Processing 43 of Set 1 | aklavik
# Processing 44 of Set 1 | mataura
# Processing 45 of Set 1 | babanusah
# City not found. Skipping...
# Processing 46 of Set 1 | vaitupu
# City not found. Skipping...
# Processing 47 of Set 1 | victoria
# Processing 48 of Set 1 | valparaiso
# Processing 49 of Set 1 | vaini
# Processing 50 of Set 1 | kirakira
# Processing 1 of Set 2 | lebu
# Processing 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing 3 of Set 2 | cape town
# Processing 4 of Set 2 | namibe
# Processing 5 of Set 2 | indiana
# Processing 6 of Set 2 | mosquera
# Processing 7 of Set 2 | port elizabeth
# Processing 8 of Set 2 | gwanda
# Processing 9 of Set 2 | tasiilaq
# Processing 10 of Set 2 | fagernes
# Processing 11 of Set 2 | ouahigouya
# Processing 12 of Set 2 | anadyr
# Processing 13 of Set 2 | yumen
# Processing 14 of Set 2 | bethel
# Processing 15 of Set 2 | bluff
# Processing 16 of Set 2 | ijaki
# City not found. Skipping...
# Processing 17 of Set 2 | pattoki
# Processing 18 of Set 2 | hualmay
# Processing 19 of Set 2 | sola
# Processing 20 of Set 2 | dingle
# Processing 21 of Set 2 | kavieng
# Processing 22 of Set 2 | kapaa
# Processing 23 of Set 2 | yatou
# Processing 24 of Set 2 | almaznyy
# Processing 25 of Set 2 | belushya guba
# City not found. Skipping...
# Processing 26 of Set 2 | camacha
# Processing 27 of Set 2 | ribeira grande
# Processing 28 of Set 2 | abu dhabi
# Processing 29 of Set 2 | bollnas
# Processing 30 of Set 2 | mahebourg
# Processing 31 of Set 2 | hobart
# Processing 32 of Set 2 | banda aceh
# Processing 33 of Set 2 | thompson
# Processing 34 of Set 2 | bud
# Processing 35 of Set 2 | alofi
# Processing 36 of Set 2 | fukue
# Processing 37 of Set 2 | puerto ayora
# Processing 38 of Set 2 | baghdad
# Processing 39 of Set 2 | albany
# Processing 40 of Set 2 | castro
# Processing 41 of Set 2 | caravelas
# Processing 42 of Set 2 | jamestown
# Processing 43 of Set 2 | dinsor
# City not found. Skipping...
# Processing 44 of Set 2 | yining
# Processing 45 of Set 2 | dikson
# Processing 46 of Set 2 | kaitangata
# Processing 47 of Set 2 | san quintin
# Processing 48 of Set 2 | laguna
# Processing 49 of Set 2 | nanortalik
# Processing 50 of Set 2 | sitka
# Processing 1 of Set 3 | deh rawud
# City not found. Skipping...
# Processing 2 of Set 3 | butaritari
# Processing 3 of Set 3 | severo-kurilsk
# Processing 4 of Set 3 | dwarka
# Processing 5 of Set 3 | mar del plata
# Processing 6 of Set 3 | tual
# Processing 7 of Set 3 | ajdabiya
# Processing 8 of Set 3 | deputatskiy
# Processing 9 of Set 3 | majene
# Processing 10 of Set 3 | chokurdakh
# Processing 11 of Set 3 | odda
# Processing 12 of Set 3 | kayerkan
# Processing 13 of Set 3 | astorga
# Processing 14 of Set 3 | barentsburg
# City not found. Skipping...
# Processing 15 of Set 3 | clyde river
# Processing 16 of Set 3 | saskylakh
# Processing 17 of Set 3 | nikolskoye
# Processing 18 of Set 3 | lolua
# City not found. Skipping...
# Processing 19 of Set 3 | talnakh
# Processing 20 of Set 3 | sao joao da barra
# Processing 21 of Set 3 | doume
# Processing 22 of Set 3 | bara
# Processing 23 of Set 3 | okha
# Processing 24 of Set 3 | avarua
# Processing 25 of Set 3 | la ronge
# Processing 26 of Set 3 | coihaique
# Processing 27 of Set 3 | mandali
# Processing 28 of Set 3 | les cayes
# Processing 29 of Set 3 | tautira
# Processing 30 of Set 3 | cordoba
# Processing 31 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing 32 of Set 3 | sunrise manor
# Processing 33 of Set 3 | hobyo
# Processing 34 of Set 3 | torbay
# Processing 35 of Set 3 | lompoc
# Processing 36 of Set 3 | marang
# Processing 37 of Set 3 | houston
# Processing 38 of Set 3 | grand river south east
# City not found. Skipping...
# Processing 39 of Set 3 | ossora
# Processing 40 of Set 3 | plettenberg bay
# Processing 41 of Set 3 | ubinskoye
# Processing 42 of Set 3 | kirkkonummi
# Processing 43 of Set 3 | balaghat
# Processing 44 of Set 3 | esperance
# Processing 45 of Set 3 | pisco
# Processing 46 of Set 3 | gazimagusa
# City not found. Skipping...
# Processing 47 of Set 3 | dubbo
# Processing 48 of Set 3 | riyadh
# Processing 49 of Set 3 | namatanai
# Processing 50 of Set 3 | pangody
# Processing 1 of Set 4 | upernavik
# Processing 2 of Set 4 | lorengau
# Processing 3 of Set 4 | walvis bay
# Processing 4 of Set 4 | port blair
# Processing 5 of Set 4 | georgetown
# Processing 6 of Set 4 | constitucion
# Processing 7 of Set 4 | bambous virieux
# Processing 8 of Set 4 | whitehorse
# Processing 9 of Set 4 | alice springs
# Processing 10 of Set 4 | nome
# Processing 11 of Set 4 | hasaki
# Processing 12 of Set 4 | springdale
# Processing 13 of Set 4 | labuhan
# Processing 14 of Set 4 | souillac
# Processing 15 of Set 4 | istisu
# Processing 16 of Set 4 | san patricio
# Processing 17 of Set 4 | ratanpur
# Processing 18 of Set 4 | luxor
# Processing 19 of Set 4 | antalaha
# Processing 20 of Set 4 | port alfred
# Processing 21 of Set 4 | camapua
# Processing 22 of Set 4 | longyearbyen
# Processing 23 of Set 4 | waingapu
# Processing 24 of Set 4 | arraial do cabo
# Processing 25 of Set 4 | bengkulu
# Processing 26 of Set 4 | merauke
# Processing 27 of Set 4 | paradwip
# City not found. Skipping...
# Processing 28 of Set 4 | nouadhibou
# Processing 29 of Set 4 | norman wells
# Processing 30 of Set 4 | costa rica
# Processing 31 of Set 4 | tuktoyaktuk
# Processing 32 of Set 4 | tsihombe
# City not found. Skipping...
# Processing 33 of Set 4 | faanui
# Processing 34 of Set 4 | kristiansund
# Processing 35 of Set 4 | labutta
# City not found. Skipping...
# Processing 36 of Set 4 | rumonge
# Processing 37 of Set 4 | arman
# Processing 38 of Set 4 | tchollire
# Processing 39 of Set 4 | longhua
# Processing 40 of Set 4 | majur
# Processing 41 of Set 4 | pincher creek
# Processing 42 of Set 4 | arlit
# Processing 43 of Set 4 | svetlyy
# Processing 44 of Set 4 | atlantis
# Processing 45 of Set 4 | grand gaube
# Processing 46 of Set 4 | vanavara
# Processing 47 of Set 4 | llanes
# Processing 48 of Set 4 | challans
# Processing 49 of Set 4 | antofagasta
# Processing 50 of Set 4 | codrington
# Processing 1 of Set 5 | roseburg
# Processing 2 of Set 5 | isangel
# Processing 3 of Set 5 | uniao da victoria
# City not found. Skipping...
# Processing 4 of Set 5 | ambilobe
# Processing 5 of Set 5 | charters towers
# Processing 6 of Set 5 | tiksi
# Processing 7 of Set 5 | port hedland
# Processing 8 of Set 5 | kwinana
# Processing 9 of Set 5 | ukiah
# Processing 10 of Set 5 | bandarbeyla
# Processing 11 of Set 5 | port lincoln
# Processing 12 of Set 5 | oksfjord
# Processing 13 of Set 5 | edmonton
# Processing 14 of Set 5 | warqla
# City not found. Skipping...
# Processing 15 of Set 5 | poco verde
# Processing 16 of Set 5 | hornepayne
# Processing 17 of Set 5 | miraflores
# Processing 18 of Set 5 | campbell river
# Processing 19 of Set 5 | chester-le-street
# Processing 20 of Set 5 | merke
# Processing 21 of Set 5 | fairbanks
# Processing 22 of Set 5 | chapais
# Processing 23 of Set 5 | ambanja
# Processing 24 of Set 5 | olafsvik
# Processing 25 of Set 5 | toliary
# City not found. Skipping...
# Processing 26 of Set 5 | ucluelet
# Processing 27 of Set 5 | chekmagush
# Processing 28 of Set 5 | mingshui
# Processing 29 of Set 5 | carnaiba
# Processing 30 of Set 5 | klaksvik
# Processing 31 of Set 5 | bargal
# City not found. Skipping...
# Processing 32 of Set 5 | luderitz
# Processing 33 of Set 5 | lasa
# Processing 34 of Set 5 | qui nhon
# Processing 35 of Set 5 | nabire
# Processing 36 of Set 5 | urcos
# Processing 37 of Set 5 | altensteig
# Processing 38 of Set 5 | eskisehir
# Processing 39 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing 40 of Set 5 | strai
# Processing 41 of Set 5 | iqaluit
# Processing 42 of Set 5 | valdivia
# Processing 43 of Set 5 | haibowan
# City not found. Skipping...
# Processing 44 of Set 5 | la orilla
# Processing 45 of Set 5 | provideniya
# Processing 46 of Set 5 | katsuura
# Processing 47 of Set 5 | ust-omchug
# Processing 48 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing 49 of Set 5 | saint marys
# Processing 50 of Set 5 | rio gallegos
# Processing 1 of Set 6 | los teques
# Processing 2 of Set 6 | le vauclin
# Processing 3 of Set 6 | demirci
# Processing 4 of Set 6 | gobabis
# Processing 5 of Set 6 | khorixas
# Processing 6 of Set 6 | ixtapa
# Processing 7 of Set 6 | fuling
# Processing 8 of Set 6 | manhattan
# Processing 9 of Set 6 | acapulco
# Processing 10 of Set 6 | jalu
# Processing 11 of Set 6 | voi
# Processing 12 of Set 6 | gizo
# Processing 13 of Set 6 | tidore
# City not found. Skipping...
# Processing 14 of Set 6 | portland
# Processing 15 of Set 6 | qaanaaq
# Processing 16 of Set 6 | tarko-sale
# Processing 17 of Set 6 | nampula
# Processing 18 of Set 6 | san lazaro
# Processing 19 of Set 6 | bakchar
# Processing 20 of Set 6 | the valley
# Processing 21 of Set 6 | tuatapere
# Processing 22 of Set 6 | vostok
# Processing 23 of Set 6 | gedo
# Processing 24 of Set 6 | asfi
# Processing 25 of Set 6 | moree
# Processing 26 of Set 6 | novoselitskoye
# Processing 27 of Set 6 | bonavista
# Processing 28 of Set 6 | uromi
# Processing 29 of Set 6 | waverly
# Processing 30 of Set 6 | puerto del rosario
# Processing 31 of Set 6 | uribia
# Processing 32 of Set 6 | mahajanga
# Processing 33 of Set 6 | meyungs
# City not found. Skipping...
# Processing 34 of Set 6 | ouesso
# Processing 35 of Set 6 | trairi
# Processing 36 of Set 6 | yulara
# Processing 37 of Set 6 | akdepe
# Processing 38 of Set 6 | ilulissat
# Processing 39 of Set 6 | bartica
# Processing 40 of Set 6 | athabasca
# Processing 41 of Set 6 | vallenar
# Processing 42 of Set 6 | maldonado
# Processing 43 of Set 6 | imbituba
# Processing 44 of Set 6 | sibolga
# Processing 45 of Set 6 | taltal
# Processing 46 of Set 6 | qasigiannguit
# Processing 47 of Set 6 | tessalit
# Processing 48 of Set 6 | nishihara
# Processing 49 of Set 6 | aktash
# Processing 50 of Set 6 | palana
# Processing 1 of Set 7 | eureka
# Processing 2 of Set 7 | keetmanshoop
# Processing 3 of Set 7 | vila franca do campo
# Processing 4 of Set 7 | shihezi
# Processing 5 of Set 7 | south lake tahoe
# Processing 6 of Set 7 | shobara
# Processing 7 of Set 7 | karaul
# City not found. Skipping...
# Processing 8 of Set 7 | arkhara
# Processing 9 of Set 7 | ise
# Processing 10 of Set 7 | staryy nadym
# Processing 11 of Set 7 | gazli
# Processing 12 of Set 7 | kimbe
# Processing 13 of Set 7 | danielskuil
# Processing 14 of Set 7 | peleduy
# Processing 15 of Set 7 | pasni
# Processing 16 of Set 7 | colac
# Processing 17 of Set 7 | never
# Processing 18 of Set 7 | lavrentiya
# Processing 19 of Set 7 | aitape
# Processing 20 of Set 7 | carnarvon
# Processing 21 of Set 7 | sartell
# Processing 22 of Set 7 | ahipara
# Processing 23 of Set 7 | palmer
# Processing 24 of Set 7 | poum
# Processing 25 of Set 7 | boende
# Processing 26 of Set 7 | oloron-sainte-marie
# Processing 27 of Set 7 | vestmannaeyjar
# Processing 28 of Set 7 | santa ana
# Processing 29 of Set 7 | marcona
# City not found. Skipping...
# Processing 30 of Set 7 | ayan
# Processing 31 of Set 7 | sindgi
# Processing 32 of Set 7 | gaeta
# Processing 33 of Set 7 | mount isa
# Processing 34 of Set 7 | finschhafen
# Processing 35 of Set 7 | kysyl-syr
# Processing 36 of Set 7 | statesville
# Processing 37 of Set 7 | burkhala
# City not found. Skipping...
# Processing 38 of Set 7 | korla
# Processing 39 of Set 7 | beyneu
# Processing 40 of Set 7 | udachnyy
# Processing 41 of Set 7 | fort saint john
# City not found. Skipping...
# Processing 42 of Set 7 | fairview
# Processing 43 of Set 7 | steubenville
# Processing 44 of Set 7 | east wenatchee bench
# Processing 45 of Set 7 | vitim
# Processing 46 of Set 7 | tawnat
# City not found. Skipping...
# Processing 47 of Set 7 | andenes
# Processing 48 of Set 7 | parit raja
# Processing 49 of Set 7 | sao filipe
# Processing 50 of Set 7 | svobodnyy
# Processing 1 of Set 8 | krasnogorskoye
# Processing 2 of Set 8 | katobu
# Processing 3 of Set 8 | fortuna
# Processing 4 of Set 8 | skjervoy
# Processing 5 of Set 8 | mehamn
# Processing 6 of Set 8 | tianpeng
# Processing 7 of Set 8 | sao miguel do araguaia
# Processing 8 of Set 8 | krasnoselkup
# Processing 9 of Set 8 | bulaevo
# Processing 10 of Set 8 | ngukurr
# City not found. Skipping...
# Processing 11 of Set 8 | lingao
# Processing 12 of Set 8 | ruwi
# Processing 13 of Set 8 | tsiroanomandidy
# Processing 14 of Set 8 | baringo
# Processing 15 of Set 8 | verkhnevilyuysk
# Processing 16 of Set 8 | hays
# Processing 17 of Set 8 | saurimo
# Processing 18 of Set 8 | najran
# Processing 19 of Set 8 | griffith
# Processing 20 of Set 8 | tabou
# Processing 21 of Set 8 | hay river
# Processing 22 of Set 8 | beringovskiy
# Processing 23 of Set 8 | narsaq
# Processing 24 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing 25 of Set 8 | wattegama
# Processing 26 of Set 8 | brae
# Processing 27 of Set 8 | padang
# Processing 28 of Set 8 | cidreira
# Processing 29 of Set 8 | atasu
# Processing 30 of Set 8 | soroti
# Processing 31 of Set 8 | cockburn town
# Processing 32 of Set 8 | huilong
# Processing 33 of Set 8 | alta floresta
# Processing 34 of Set 8 | crab hill
# City not found. Skipping...
# Processing 35 of Set 8 | coquimbo
# Processing 36 of Set 8 | bosaso
# Processing 37 of Set 8 | saint george
# Processing 38 of Set 8 | ulladulla
# Processing 39 of Set 8 | port macquarie
# Processing 40 of Set 8 | vernon
# Processing 41 of Set 8 | qafsah
# City not found. Skipping...
# Processing 42 of Set 8 | gat
# Processing 43 of Set 8 | jennings
# Processing 44 of Set 8 | hofn
# Processing 45 of Set 8 | capreol
# Processing 46 of Set 8 | vila velha
# Processing 47 of Set 8 | pingzhuang
# Processing 48 of Set 8 | levelland
# Processing 49 of Set 8 | tuxpan
# Processing 50 of Set 8 | fort dix
# Processing 1 of Set 9 | cayenne
# Processing 2 of Set 9 | nemuro
# Processing 3 of Set 9 | masuguru
# Processing 4 of Set 9 | beaverlodge
# Processing 5 of Set 9 | inuvik
# Processing 6 of Set 9 | kruisfontein
# Processing 7 of Set 9 | tambul
# City not found. Skipping...
# Processing 8 of Set 9 | nanakuli
# Processing 9 of Set 9 | laranjal paulista
# Processing 10 of Set 9 | constantine
# Processing 11 of Set 9 | touros
# Processing 12 of Set 9 | khatanga
# Processing 13 of Set 9 | sistranda
# Processing 14 of Set 9 | srandakan
# Processing 15 of Set 9 | kavaratti
# Processing 16 of Set 9 | sur
# Processing 17 of Set 9 | pochutla
# Processing 18 of Set 9 | obzor
# Processing 19 of Set 9 | tura
# Processing 20 of Set 9 | touba
# Processing 21 of Set 9 | grindavik
# Processing 22 of Set 9 | bako
# Processing 23 of Set 9 | visby
# Processing 24 of Set 9 | makakilo city
# Processing 25 of Set 9 | taoudenni
# Processing 26 of Set 9 | luganville
# Processing 27 of Set 9 | neustrelitz
# Processing 28 of Set 9 | brownsville
# Processing 29 of Set 9 | tevaitoa
# Processing 30 of Set 9 | comodoro rivadavia
# Processing 31 of Set 9 | asau
# Processing 32 of Set 9 | chagda
# City not found. Skipping...
# Processing 33 of Set 9 | pevek
# Processing 34 of Set 9 | west wendover
# Processing 35 of Set 9 | kegayli
# City not found. Skipping...
# Processing 36 of Set 9 | half moon bay
# Processing 37 of Set 9 | camopi
# Processing 38 of Set 9 | praia da vitoria
# Processing 39 of Set 9 | villa carlos paz
# Processing 40 of Set 9 | veraval
# Processing 41 of Set 9 | nouakchott
# Processing 42 of Set 9 | kastamonu
# Processing 43 of Set 9 | maghama
# City not found. Skipping...
# Processing 44 of Set 9 | rudsar
# Processing 45 of Set 9 | rio grande
# Processing 46 of Set 9 | biak
# Processing 47 of Set 9 | dunedin
# Processing 48 of Set 9 | keuruu
# Processing 49 of Set 9 | bukama
# Processing 50 of Set 9 | kristinehamn
# Processing 1 of Set 10 | hovd
# Processing 2 of Set 10 | kaka
# Processing 3 of Set 10 | ishinomaki
# Processing 4 of Set 10 | palu
# Processing 5 of Set 10 | bahar
# Processing 6 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing 7 of Set 10 | kalmunai
# Processing 8 of Set 10 | manacapuru
# Processing 9 of Set 10 | kuhdasht
# Processing 10 of Set 10 | phan rang
# City not found. Skipping...
# Processing 11 of Set 10 | rajshahi
# Processing 12 of Set 10 | cabano
# Processing 13 of Set 10 | saint anthony
# Processing 14 of Set 10 | alyangula
# Processing 15 of Set 10 | bayan
# Processing 16 of Set 10 | felanitx
# Processing 17 of Set 10 | mingaora
# Processing 18 of Set 10 | margate
# Processing 19 of Set 10 | la union
# Processing 20 of Set 10 | nara
# Processing 21 of Set 10 | tagusao
# Processing 22 of Set 10 | americus
# Processing 23 of Set 10 | itarema
# Processing 24 of Set 10 | saint-pierre
# Processing 25 of Set 10 | galiwinku
# City not found. Skipping...
# Processing 26 of Set 10 | amderma
# City not found. Skipping...
# Processing 27 of Set 10 | riachao das neves
# Processing 28 of Set 10 | hamilton
# Processing 29 of Set 10 | saldanha
# Processing 30 of Set 10 | salalah
# Processing 31 of Set 10 | cabo san lucas
# Processing 32 of Set 10 | meulaboh
# Processing 33 of Set 10 | gushikawa
# Processing 34 of Set 10 | geraldton
# Processing 35 of Set 10 | marsh harbour
# Processing 36 of Set 10 | komsomolskiy
# Processing 37 of Set 10 | fort frances
# Processing 38 of Set 10 | rudbar
# Processing 39 of Set 10 | champerico
# Processing 40 of Set 10 | ronne
# Processing 41 of Set 10 | saleaula
# City not found. Skipping...
# Processing 42 of Set 10 | tiarei
# Processing 43 of Set 10 | mogzon
# Processing 44 of Set 10 | porteirinha
# Processing 45 of Set 10 | louisbourg
# City not found. Skipping...
# Processing 46 of Set 10 | lukovo
# Processing 47 of Set 10 | imeni poliny osipenko
# Processing 48 of Set 10 | srednekolymsk
# Processing 49 of Set 10 | kharabali
# Processing 50 of Set 10 | rafaela
# Processing 1 of Set 11 | college
# Processing 2 of Set 11 | odienne
# Processing 3 of Set 11 | shimoda
# Processing 4 of Set 11 | saint-leu
# Processing 5 of Set 11 | san ramon
# Processing 6 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing 7 of Set 11 | acarau
# Processing 8 of Set 11 | marfino
# Processing 9 of Set 11 | phan thiet
# Processing 10 of Set 11 | buraydah
# Processing 11 of Set 11 | timbiqui
# Processing 12 of Set 11 | wanning
# Processing 13 of Set 11 | viedma
# Processing 14 of Set 11 | muros
# Processing 15 of Set 11 | los llanos de aridane
# Processing 16 of Set 11 | abbeville
# Processing 17 of Set 11 | el astillero
# Processing 18 of Set 11 | tairua
# Processing 19 of Set 11 | nieuw amsterdam
# Processing 20 of Set 11 | thinadhoo
# Processing 21 of Set 11 | longlac
# City not found. Skipping...
# Processing 22 of Set 11 | sorland
# Processing 23 of Set 11 | vardo
# Processing 24 of Set 11 | inhambane
# Processing 25 of Set 11 | sirsi
# Processing 26 of Set 11 | pingxiang
# Processing 27 of Set 11 | umm kaddadah
# Processing 28 of Set 11 | yerbogachen
# Processing 29 of Set 11 | pearl
# Processing 30 of Set 11 | kedougou
# Processing 31 of Set 11 | mandla
# Processing 32 of Set 11 | darovskoy
# Processing 33 of Set 11 | kawana waters
# City not found. Skipping...
# Processing 34 of Set 11 | hohhot
# Processing 35 of Set 11 | vao
# Processing 36 of Set 11 | kulhudhuffushi
# Processing 37 of Set 11 | sisimiut
# Processing 38 of Set 11 | yenagoa
# Processing 39 of Set 11 | goundam
# Processing 40 of Set 11 | bobrovytsya
# Processing 41 of Set 11 | faya
# Processing 42 of Set 11 | fort nelson
# Processing 43 of Set 11 | kyzyl-suu
# Processing 44 of Set 11 | turmalina
# Processing 45 of Set 11 | sinop
# Processing 46 of Set 11 | honningsvag
# Processing 47 of Set 11 | carauari
# Processing 48 of Set 11 | esil
# Processing 49 of Set 11 | roman
# Processing 50 of Set 11 | la rioja
# Processing 1 of Set 12 | sioux lookout
# Processing 2 of Set 12 | paamiut
# Processing 3 of Set 12 | toftir
# City not found. Skipping...
# Processing 4 of Set 12 | perleberg
# Processing 5 of Set 12 | burica
# City not found. Skipping...
# Processing 6 of Set 12 | tabiauea
# City not found. Skipping...
# Processing 7 of Set 12 | sault sainte marie
# Processing 8 of Set 12 | kayes
# Processing 9 of Set 12 | barawe
# City not found. Skipping...
# Processing 10 of Set 12 | ciudad guayana
# Processing 11 of Set 12 | egvekinot
# Processing 12 of Set 12 | khonuu
# City not found. Skipping...
# Processing 13 of Set 12 | winnemucca
# Processing 14 of Set 12 | cazaje
# City not found. Skipping...
# Processing 15 of Set 12 | vaitape
# Processing 16 of Set 12 | tangjiazhuang
# Processing 17 of Set 12 | saint-ambroise
# Processing 18 of Set 12 | husavik
# Processing 19 of Set 12 | lewistown
# Processing 20 of Set 12 | peace river
# Processing 21 of Set 12 | mount gambier
# Processing 22 of Set 12 | lyngseidet
# Processing 23 of Set 12 | samusu
# City not found. Skipping...
# Processing 24 of Set 12 | vestmanna
# Processing 25 of Set 12 | ancud
# Processing 26 of Set 12 | calvinia
# Processing 27 of Set 12 | mackenzie
# Processing 28 of Set 12 | harindanga
# Processing 29 of Set 12 | mananjary
# Processing 30 of Set 12 | gonzalez
# Processing 31 of Set 12 | porosozero
# Processing 32 of Set 12 | maniitsoq
# Processing 33 of Set 12 | hami
# Processing 34 of Set 12 | avera
# Processing 35 of Set 12 | sarai naurang
# Processing 36 of Set 12 | petropavlovsk-kamchatskiy
# Processing 37 of Set 12 | wabag
# Processing 38 of Set 12 | belmonte
# Processing 39 of Set 12 | ponta do sol
# Processing 40 of Set 12 | amahai
# Processing 41 of Set 12 | general pico
# Processing 42 of Set 12 | spring
# Processing 43 of Set 12 | sao mateus
# Processing 44 of Set 12 | pemangkat
# Processing 45 of Set 12 | nakamura
# Processing 46 of Set 12 | antsohihy
# Processing 47 of Set 12 | carballo
# Processing 48 of Set 12 | qostanay
# Processing 49 of Set 12 | kurilsk
# Processing 50 of Set 12 | schoneiche
# Processing 1 of Set 13 | bambanglipuro
# Processing 2 of Set 13 | takoradi
# Processing 3 of Set 13 | barbar
# City not found. Skipping...
# Processing 4 of Set 13 | itoman
# Processing 5 of Set 13 | taunton
# Processing 6 of Set 13 | rudiskes
# Processing 7 of Set 13 | santa isabel do rio negro
# -----------------------
# Data Retrieval Complete
# -----------------------

# %%
len(city_data)
# Out:
# 550

# %%
# Convert city_data list to a DataFrame
city_data_df = pd.DataFrame(city_data)

new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                           City Country      Lat       Lng  Max Temp  Humidity  \
# 0                   Port Hardy      CA  50.6996 -127.4199     38.75        93
# 1                         Mayo      US  38.8876  -76.5119     60.42        52
# 2                Moose Factory      CA  51.2585  -80.6094      8.60        66
# 3                     Cherskiy      RU  68.7500  161.3000    -30.91       100
# 4                         Chuy      UY -33.6971  -53.4616     70.97        67
# ..                         ...     ...      ...       ...       ...       ...
# 545                   Takoradi      GH   4.8845   -1.7554     81.32        78
# 546                     Itoman      JP  26.1247  127.6694     64.42        55
# 547                    Taunton      GB  51.0211   -3.1047     44.87        81
# 548                   Rudiskes      LT  54.5167   24.8333     29.21        94
# 549  Santa Isabel Do Rio Negro      BR  -0.4139  -65.0192     83.08        83
#
#      Cloudiness  Wind Speed          Current Description
# 0            90        5.75  light intensity shower rain
# 1             1        1.99                    clear sky
# 2             1        9.22                    clear sky
# 3            77        4.23                broken clouds
# 4           100       11.68              overcast clouds
# ..          ...         ...                          ...
# 545          24        8.19                   few clouds
# 546          75        8.05                broken clouds
# 547          13        3.00                   few clouds
# 548         100        6.51                   light snow
# 549          99        1.88              overcast clouds
#
# [550 rows x 9 columns]

# %%
#Create the output file (CSV)
output_data_file = "./Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
